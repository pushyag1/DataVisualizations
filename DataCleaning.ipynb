# %% [markdown]
# <a href="https://colab.research.google.com/github/pushyag1/DataVisualizations/blob/master/DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#t="State_to_State_Migrations_Table_2017.csv"
df= pd.read_excel("https://www2.census.gov/programs-surveys/demo/tables/geographic-mobility/2005/state-to-state-migration/state_to_state_migrations_table_2005.xls",header=[5,6], index_col = 0)
df.head(10)
# Out:
# Current residence in -- Residence 1 year ago in --  ...
#                                            Alabama  ... Wyoming.1
# NaN                                       Estimate  ...       MOE
# NaN                                            NaN  ...       NaN
# Alabama                                     580353  ...       507
# Alaska                                         152  ...       353
# Arizona                                       1427  ...       811
# Arkansas                                      1894  ...        71
# California                                    4375  ...      1003
# NaN                                            NaN  ...       NaN
# Colorado                                      1495  ...      2494
# Connecticut                                    520  ...       274
#
# [10 rows x 114 columns]

# %%
df.tail(10)
# Out:
# Current residence in --                            Residence 1 year ago in --  ...
#                                                                       Alabama  ... Wyoming.1
# Vermont                                                                     0  ...        35
# Virginia                                                                 2150  ...       292
# Washington                                                                184  ...       394
# West Virginia                                                             347  ...        99
# NaN                                                                       NaN  ...       NaN
# Wisconsin                                                                2275  ...       560
# Wyoming                                                                   268  ...      6023
# Footnotes:                                                                NaN  ...       NaN
# ...

# %%
#df = df.iloc[5:]  #removing first 5 rows

# %%
df.head()
# Out:
# Current residence in -- Residence 1 year ago in --  ...
#                                            Alabama  ... Wyoming.1
# NaN                                       Estimate  ...       MOE
# NaN                                            NaN  ...       NaN
# Alabama                                     580353  ...       507
# Alaska                                         152  ...       353
# Arizona                                       1427  ...       811
#
# [5 rows x 114 columns]

# %%
df = df.iloc[:-9]  #removing last 9 rows

# %%
df.tail()
# Out:
# Current residence in -- Residence 1 year ago in --            ...
#                                            Alabama Alabama.1  ... Wyoming Wyoming.1
# Tennessee                                     8546      2232  ...     453       436
# Texas                                         7042      2767  ...    1600       765
# NaN                                            NaN       NaN  ...     NaN       NaN
# Utah                                             0       258  ...     746       526
# Vermont                                          0       211  ...      19        35
#
# [5 rows x 114 columns]

# %%
df=df.drop(columns=df.columns[(df == 'MOE').any()])
#df=df.drop(columns=df.header[(df == 'Total').any()])

# %%
df.shape
# Out:
# (62, 62)

# %%
df.head(10)
# Out:
# Current residence in -- Residence 1 year ago in --  ...
#                                            Alabama  ...   Wyoming
# NaN                                       Estimate  ...  Estimate
# NaN                                            NaN  ...       NaN
# Alabama                                     580353  ...       436
# Alaska                                         152  ...       222
# Arizona                                       1427  ...      1458
# Arkansas                                      1894  ...        41
# California                                    4375  ...      1425
# NaN                                            NaN  ...       NaN
# Colorado                                      1495  ...      5690
# Connecticut                                    520  ...         0
#
# [10 rows x 62 columns]

# %%
#df = df.drop(df.index[[0,3]]) #do drop 9th row(unitedstates2)
#df

# %%
df.set_index(df.iloc[:, 0].name) #to set first column as index
# Out:
# Current residence in --               Residence 1 year ago in --  ...
#                                                           Alaska  ...   Wyoming
# (Residence 1 year ago in --, Alabama)                             ...
# Estimate                                                Estimate  ...  Estimate
# NaN                                                          NaN  ...       NaN
# 580353                                                       608  ...       436
# 152                                                        84150  ...       222
# 1427                                                        1836  ...      1458
# ...                                                          ...  ...       ...
# 8546                                                         595  ...       453
# 7042                                                        3656  ...      1600
# NaN                                                          NaN  ...       NaN
# ...

# %%
df = df.dropna(axis = 0, how = 'all') #dropping rows with all nan values
df
# Out:
# Current residence in --  Residence 1 year ago in --  ...
#                                             Alabama  ...   Wyoming
# NaN                                        Estimate  ...  Estimate
# Alabama                                      580353  ...       436
# Alaska                                          152  ...       222
# Arizona                                        1427  ...      1458
# Arkansas                                       1894  ...        41
# California                                     4375  ...      1425
# Colorado                                       1495  ...      5690
# Connecticut                                     520  ...         0
# Delaware                                        546  ...         0
# District of Columbia                              0  ...         0
# Florida                                       10559  ...       873
# Georgia                                       22111  ...         0
# ...

# %%
#df.reset_index()

# %%
df = df.drop(df.index[[0,1,29,30,31]])
df
# Out:
# Current residence in -- Residence 1 year ago in --  ...
#                                            Alabama  ... Wyoming
# Alaska                                         152  ...     222
# Arizona                                       1427  ...    1458
# Arkansas                                      1894  ...      41
# California                                    4375  ...    1425
# Colorado                                      1495  ...    5690
# Connecticut                                    520  ...       0
# Delaware                                       546  ...       0
# District of Columbia                             0  ...       0
# Florida                                      10559  ...     873
# Georgia                                      22111  ...       0
# Hawaii                                        1464  ...     113
# Idaho                                          185  ...    1177
# Illinois                                      1551  ...      78
# ...

# %%
#df.columns = (df.columns.get_level_values(0)[:3].tolist() +  df.columns.get_level_values(0)[3:].tolist())
#df.head(10)

# %%
#df.columns.get_level_values(0)[:3]

# %%
#df.columns.get_level_values(0)[3:]

# %%
d=df.T
d
# Out:
#                                                  Alaska  ...  Vermont
# Current residence in --                                  ...
# Residence 1 year ago in -- Alabama                  152  ...        0
#                            Alaska                 84150  ...       15
#                            Arizona                  883  ...       92
#                            Arkansas                  54  ...        0
#                            California              3898  ...      290
# ...                                                 ...  ...      ...
#                            Washington              5711  ...      215
#                            West Virginia              0  ...       98
# Current residence in --    Unnamed: 110_level_1  Alaska  ...  Vermont
# Residence 1 year ago in -- Wisconsin                765  ...        0
#                            Wyoming                  222  ...       19
#
# [62 rows x 44 columns]

# %%
d.reset_index(level=0, inplace=True)
d
# Out:
#                          Current residence in --  Alaska  ...   Utah  Vermont
# Alabama               Residence 1 year ago in --     152  ...      0        0
# Alaska                Residence 1 year ago in --   84150  ...    500       15
# Arizona               Residence 1 year ago in --     883  ...   6222       92
# Arkansas              Residence 1 year ago in --      54  ...     77        0
# California            Residence 1 year ago in --    3898  ...  17879      290
# ...                                          ...     ...  ...    ...      ...
# Washington            Residence 1 year ago in --    5711  ...   3773      215
# West Virginia         Residence 1 year ago in --       0  ...    362       98
# Unnamed: 110_level_1     Current residence in --  Alaska  ...   Utah  Vermont
# Wisconsin             Residence 1 year ago in --     765  ...    764        0
# Wyoming               Residence 1 year ago in --     222  ...    746       19
#
# [62 rows x 45 columns]

# %%
d.reset_index(level=0, inplace=True)
d
# Out:
#                    index     Current residence in --  ...   Utah  Vermont
# 0                Alabama  Residence 1 year ago in --  ...      0        0
# 1                 Alaska  Residence 1 year ago in --  ...    500       15
# 2                Arizona  Residence 1 year ago in --  ...   6222       92
# 3               Arkansas  Residence 1 year ago in --  ...     77        0
# 4             California  Residence 1 year ago in --  ...  17879      290
# ..                   ...                         ...  ...    ...      ...
# 57            Washington  Residence 1 year ago in --  ...   3773      215
# 58         West Virginia  Residence 1 year ago in --  ...    362       98
# 59  Unnamed: 110_level_1     Current residence in --  ...   Utah  Vermont
# 60             Wisconsin  Residence 1 year ago in --  ...    764        0
# 61               Wyoming  Residence 1 year ago in --  ...    746       19
#
# [62 rows x 46 columns]

# %%
#d.reset_index(level=0, inplace=True)

# %%
d.columns
# Out:
# Index(['index', 'Current residence in --', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia ', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'New Jersey',
#        'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio',
#        'Oklahoma', 'Oregon', 'Pennsylvania', 'Puerto Rico', 'Rhode Island',
#        'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah',
#        'Vermont'],
#       dtype='object')

# %%
#d['col'] = d[['index', 'Current residence in --']].apply(lambda x: ''.join(x), axis=1)
#d['col']=d['index'].astype(str) + d['Current residence in --']

# %%
#df.stack(level=0).reset_index(level=-1).rename({'level_1': 'New'}, axis=1)

# %%
#d=d.drop(columns=d.columns[(d == 'Total').any()])

# %%
d.columns
# Out:
# Index(['index', 'Current residence in --', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia ', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'New Jersey',
#        'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio',
#        'Oklahoma', 'Oregon', 'Pennsylvania', 'Puerto Rico', 'Rhode Island',
#        'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah',
#        'Vermont'],
#       dtype='object')

# %%
d['col']=[''.join(i) for i in zip(d["index"].map(str),d["Current residence in --"])]

# %% [markdown]
# https://stackoverflow.com/questions/59837241/combine-first-row-and-header-with-pandas
# https://stackoverflow.com/questions/46190263/merge-the-first-row-with-the-column-headers-in-a-dataframe

# %%
col_name="col"
first_col = d.pop(col_name)

# %%
d.head()
# Out:
#         index     Current residence in -- Alaska  ...  Texas   Utah Vermont
# 0     Alabama  Residence 1 year ago in --    152  ...   7042      0       0
# 1      Alaska  Residence 1 year ago in --  84150  ...   3656    500      15
# 2     Arizona  Residence 1 year ago in --    883  ...  12180   6222      92
# 3    Arkansas  Residence 1 year ago in --     54  ...   9653     77       0
# 4  California  Residence 1 year ago in --   3898  ...  74777  17879     290
#
# [5 rows x 46 columns]

# %%
d.shape
# Out:
# (62, 46)

# %%
d.insert(0, col_name, first_col)

# %%
d
# Out:
#                                             col  ...  Vermont
# 0             AlabamaResidence 1 year ago in --  ...        0
# 1              AlaskaResidence 1 year ago in --  ...       15
# 2             ArizonaResidence 1 year ago in --  ...       92
# 3            ArkansasResidence 1 year ago in --  ...        0
# 4          CaliforniaResidence 1 year ago in --  ...      290
# ..                                          ...  ...      ...
# 57         WashingtonResidence 1 year ago in --  ...      215
# 58      West VirginiaResidence 1 year ago in --  ...       98
# 59  Unnamed: 110_level_1Current residence in --  ...  Vermont
# 60          WisconsinResidence 1 year ago in --  ...        0
# 61            WyomingResidence 1 year ago in --  ...       19
#
# [62 rows x 47 columns]

# %%
d=d.drop(['index', 'Current residence in --'], axis = 1)

# %%
d
# Out:
#                                             col  Alaska  ...   Utah  Vermont
# 0             AlabamaResidence 1 year ago in --     152  ...      0        0
# 1              AlaskaResidence 1 year ago in --   84150  ...    500       15
# 2             ArizonaResidence 1 year ago in --     883  ...   6222       92
# 3            ArkansasResidence 1 year ago in --      54  ...     77        0
# 4          CaliforniaResidence 1 year ago in --    3898  ...  17879      290
# ..                                          ...     ...  ...    ...      ...
# 57         WashingtonResidence 1 year ago in --    5711  ...   3773      215
# 58      West VirginiaResidence 1 year ago in --       0  ...    362       98
# 59  Unnamed: 110_level_1Current residence in --  Alaska  ...   Utah  Vermont
# 60          WisconsinResidence 1 year ago in --     765  ...    764        0
# 61            WyomingResidence 1 year ago in --     222  ...    746       19
#
# [62 rows x 45 columns]

# %%
d=d.T

# %%
d
# Out:
#                                                       0   ...                                 61
# col                    AlabamaResidence 1 year ago in --  ...  WyomingResidence 1 year ago in --
# Alaska                                               152  ...                                222
# Arizona                                             1427  ...                               1458
# Arkansas                                            1894  ...                                 41
# California                                          4375  ...                               1425
# Colorado                                            1495  ...                               5690
# Connecticut                                          520  ...                                  0
# Delaware                                             546  ...                                  0
# District of Columbia                                   0  ...                                  0
# ...

# %%
new_header = d.iloc[0] #grab the first row for the header
d = d[1:] #take the data less the header row
d.columns = new_header #set the header row as the df header

# %%
d
# Out:
# col                   AlabamaResidence 1 year ago in --  ... WyomingResidence 1 year ago in --
# Alaska                                              152  ...                               222
# Arizona                                            1427  ...                              1458
# Arkansas                                           1894  ...                                41
# California                                         4375  ...                              1425
# Colorado                                           1495  ...                              5690
# Connecticut                                         520  ...                                 0
# Delaware                                            546  ...                                 0
# District of Columbia                                  0  ...                                 0
# Florida                                           10559  ...                               873
# ...
